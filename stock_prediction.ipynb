# %%
from stock import Stock

stock = Stock(ticker='ONGC', exchange='NSE')
# Out:
# Using Theano backend.
#               Open    High     Low    Last   Close  Total Trade Quantity  \
# Date
# 1998-03-24  247.95  256.50  241.90  250.25  250.20               15800.0
# 1998-03-25  255.00  275.25  255.00  275.25  275.25               20400.0
# 1998-03-26  290.00  290.00  268.75  272.00  272.65               18700.0
# 1998-03-27  268.95  275.50  268.95  274.90  274.70                5900.0
# 1998-03-30  277.00  281.95  265.00  265.00  266.45                8400.0
#
#             Turnover (Lacs)
# Date
# 1998-03-24            39.26
# 1998-03-25            54.75
# 1998-03-26            52.13
# 1998-03-27            16.12
# 1998-03-30            22.87
#               Open    High     Low    Last   Close  Total Trade Quantity  \
# Date
# 2018-08-01  165.25  168.75  165.15  167.15  167.20             4618179.0
# 2018-08-02  169.40  170.80  165.25  167.10  166.40             7825776.0
# 2018-08-03  170.40  171.00  166.20  166.60  166.80            12172870.0
# ...

# %%
stock.plot_stock_history()
stock.load_data_set()
stock.normalize()
stock.split_data_set()
stock.reshape_input()
