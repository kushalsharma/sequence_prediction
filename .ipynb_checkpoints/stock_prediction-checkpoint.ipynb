# %%
from stock import Stock

stock = Stock(ticker='BATAINDIA', exchange='NSE')
# Out:
# Using Theano backend.
# BATAINDIA Stock Initialized. Data covers 1998-03-23 to 2018-08-07.

# %%
stock.plot_stock_history()
stock.load_data_set()
stock.normalize()
stock.split_data_set()
# Out:
# [[0.10378494]
#  [0.10254735]
#  [0.10653512]
#  ...
#  [0.48021589]
#  [0.48416927]
#  [0.47646877]]
# [[0.47932208]
#  [0.47987212]
#  [0.47138093]
#  ...
#  [0.62714428]
#  [0.6243941 ]
#  [0.64134209]]
